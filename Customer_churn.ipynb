# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df= pd.read_csv('customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
customer_5= df.iloc[:, 4]
customer_5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
customer_15= df.iloc[:, 14]
customer_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
seniour_male_electronic= df[(df['gender']== 'Male') & (df['SeniorCitizen']== 1) & (df['PaymentMethod']== 'Electronic check')]
seniour_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_total_tenure= df[(df['tenure']> 70) | (df['MonthlyCharges']> 100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
two_mail_yes= df[(df['Contract']== 'Two year') & (df['PaymentMethod']== 'Mailed check') & (df['Churn']== 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
from random import sample

# %%
customer_333= df.sample(n= 333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4542  9029-FEGVJ  Female              1     Yes         No      32
# 4438  2263-SFSQZ    Male              0     Yes        Yes      51
# 4693  0463-TXOAK    Male              0      No        Yes      52
# 4228  6416-TVAIH    Male              0     Yes        Yes       1
# 1307  1866-NXPSP  Female              0      No         No      36
# ...          ...     ...            ...     ...        ...     ...
# 2851  1897-OKVMW  Female              0     Yes        Yes      64
# 717   9944-AEXBM    Male              0      No         No      32
# 1004  7047-YXDMZ    Male              0      No         No      21
# 4858  3950-VPYJB    Male              0     Yes        Yes      57
# 5776  4291-TPNFG    Male              0     Yes         No      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4542          Yes           Yes     Fiber optic                   No  ...
# ...

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# ### Data visualization

# %%
#sns.barplot(x= df['InternetService'])
plt.bar(df['InternetService'].value_counts().keys().tolist(), df['InternetService'].value_counts().values.tolist())
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of categories')
plt.title('Distribution of Internet Service')
plt.show()

# %%
sns.countplot(x= df['InternetService'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
plt.hist(x= df['tenure'], bins=30,color= 'green')
plt.title('Dsitribution of tenure')
# Out:
# Text(0.5, 1.0, 'Dsitribution of tenure')

# %%
plt.scatter(x= df['tenure'], y= df['MonthlyCharges'], color= 'brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly charges of customer')
plt.title('Tenure VS Monthly charges')
plt.show()

# %%
sns.boxplot(x= df['Contract'], y= df['tenure'])
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
df.boxplot(by= ['Contract'], column= ['tenure'])
# Out:
# <Axes: title={'center': 'tenure'}, xlabel='[Contract]'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

y=df[['MonthlyCharges']]
x= df[['tenure']]

# %%
x.head()
# Out:
#    tenure
# 0       1
# 1      34
# 2       2
# 3      45
# 4       2

# %%
y.head()
# Out:
#    MonthlyCharges
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.3, random_state= 24)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((4930, 1), (2113, 1), (4930, 1), (2113, 1))

# %%
lr= LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(x_test)
y_pred[:5], y_test[:5]
# Out:
# (array([[58.90506033],
#         [74.33571515],
#         [59.83089962],
#         [57.67060795],
#         [56.12754247]]),
#        MonthlyCharges
#  261           106.90
#  490           104.80
#  3026           84.95
#  6619           20.15
#  2677           70.05)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 29.457334065699946

# %% [markdown]
# ### Logistic Regression

# %%
x= df[['MonthlyCharges']]
y= df[['Churn']]

x_train,x_test,y_train,y_test= train_test_split(x,y, test_size= 0.35, random_state= 9)

# %%
from sklearn.linear_model import LogisticRegression
lo= LogisticRegression()
lo.fit(x_train, y_train)
# Out:
# C:\Users\Jay Parmar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred= lo.predict(x_test)

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7254663422546634

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1789,    0],
#        [ 677,    0]], dtype=int64)

# %%
x= df[['tenure', 'MonthlyCharges']]
y= df[['Churn']]

x_train,x_test,y_train,y_test= train_test_split(x,y, test_size= 0.2, random_state= 9)
lo.fit(x_train, y_train)
# Out:
# C:\Users\Jay Parmar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred= lo.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7920511000709723

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[954,  90],
#        [203, 162]], dtype=int64)

# %% [markdown]
# ### Decision Tree

# %%
x= df[['tenure']]
y= df[['Churn']]

x_train,x_test,y_train,y_test= train_test_split(x,y, test_size= 0.2, random_state= 9)
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred= dt.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7452093683463449

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[940, 104],
#        [255, 110]], dtype=int64)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()

x= df[['tenure', 'MonthlyCharges']]
y= df[['Churn']]
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size= 0.35, random_state= 9)

# %%
rf.fit(x_train , y_train)
# Out:
# C:\Users\Jay Parmar\AppData\Local\Temp\ipykernel_10376\3990742091.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train , y_train)
# RandomForestClassifier()

# %%
y_pred= rf.predict(x_test)
accuracy_score(y_test, y_pred), confusion_matrix(y_test, y_pred)
# Out:
# (0.7445255474452555,
#  array([[1544,  245],
#         [ 385,  292]], dtype=int64))
